# %%
from dputils.scrape import Scraper, Tag

# %%
def get_data(query, page=1):
    scraper = Scraper(f'https://www.amazon.in/s?k={query}&page={page}')
    print(scraper.soup.title)
    target= Tag(cls='s-main-slot s-result-list s-search-results sg-row')
    items= Tag(cls='s-result-item')
    brand = Tag('h5')
    title = Tag('h2')
    price = Tag('span',cls='a-price-whole')
    rating = Tag('span', cls='a-size-base')
    oprice = Tag('span', cls='a-offscreen')
    return scraper.get_all(target, items,
        brand=brand, title=title, price=price, 
        rating=rating, oprice=oprice)

# %%
query = 'watch'

all_data = []
for i in range(1,11):
    print(f'fetching page {i} data')
    data = get_data(query, i)
    if len(data) == 0:
        print('No more data')
        break
    all_data.extend(data)
all_data
# Out:
# fetching page 1 data
# <title>Amazon.in : watch</title>
# fetching page 2 data
# <title>Amazon.in : watch</title>
# fetching page 3 data
# <title>Amazon.in : watch</title>
# fetching page 4 data
# <title>Amazon.in : watch</title>
# fetching page 5 data
# <title>Amazon.in : watch</title>
# fetching page 6 data
# <title>Amazon.in : watch</title>
# fetching page 7 data
# <title>Amazon.in : watch</title>
# fetching page 8 data
# <title>Amazon.in : watch</title>
# fetching page 9 data
# <title>Amazon.in : watch</title>
# fetching page 10 data
# <title>Amazon.in : watch</title>
# [{'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'TIMEX',
#   'title': "Analog Silver Dial Men's Watch-TWTG31SMU03  ",
#   'price': '1,598',
#   'rating': 'No reviews',
#   'oprice': '₹1,598'},
#  {'brand': 'TIMEX',
#   'title': "Analog Blue Dial Men's Watch-TWHG03SMU14  ",
#   'price': '2,498',
#   'rating': '4.1',
#   'oprice': '₹2,498'},
#  {'brand': 'TIMEX',
#   'title': "Analog Silver Dial Men's Watch-TWHG03SMU16  ",
#   'price': '2,919',
#   'rating': '4.2',
#   'oprice': '₹2,919'},
#  {'brand': 'TIMEX',
#   'title': "Analog Black Dial Men's Watch-TWHG35SMU05  ",
#   'price': '1,799',
#   'rating': '4.1',
#   'oprice': '₹1,799'},
#  {'brand': 'USM',
#   'title': 'USM ID116 Smart Watch Smart Bracelet Fitness Tracker Color Screen Smartwatch Heart Rate Blood Pressure Pedometer Sleep Monitor  ',
#   'price': '329',
#   'rating': '4.6',
#   'oprice': '₹329'},
#  {'brand': 'boAt',
#   'title': 'boAt Flash Edition Smart Watch with Activity Tracker, Multiple Sports Modes, 1.3" Screen, 170+ Watch Faces, Sleep Monitor, Gesture, Camera & Music Control, IP68 & 7 Days Battery Life(Lightning Black)  ',
#   'price': '1,499',
#   'rating': '4.0',
#   'oprice': '₹1,499'},
#  {'brand': 'boAt',
#   'title': 'boAt Wave Prime47 Smart Watch with 1.69" HD Display, 700+ Active Modes, ASAP Charge, Live Cricket Scores, Crest App Health Ecosystem, HR & SpO2 Monitoring(Matte Black)  ',
#   'price': '1,199',
#   'rating': '3.4',
#   'oprice': '₹1,199'},
#  {'brand': 'MARCLEX',
#   'title': "Affordable Men's Watch, Men's LED Digital Watch, Watch for Boys & Gents Watches Combo Pack of 2  ",
#   'price': '249',
#   'rating': '5.0',
#   'oprice': '₹249'},
#  {'brand': 'MARCLEX',
#   'title': "Affordable Men's Watch, Men's LED Digital Watch, Watch for Boys & Gents Watches Combo Pack of 2  ",
#   'price': '249',
#   'rating': '5.0',
#   'oprice': '₹249'},
#  {'brand': 'Renaissance Traders',
#   'title': "Analogue Women's Watch (White Dial Rose Gold Colored Strap)  ",
#   'price': '249',
#   'rating': '4.0',
#   'oprice': '₹249'},
#  {'brand': 'IIK COLLECTION',
#   'title': 'Watches for Women Round Studded Dial |Analogue Quartz Movemnet Ladies Watch|Long Battery Life|Stainless Steel Adjustable Bracelet Chain Strap|Double Lock Clasp Safety Watches for Girls  ',
#   'price': '349',
#   'rating': '4.8',
#   'oprice': '₹349'},
#  {'brand': 'CLOUDWOOD',
#   'title': 'Digital Vintage Square Dial Unisex Wrist Watch for Men & Women -W70  ',
#   'price': '299',
#   'rating': '4.0',
#   'oprice': '₹299'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '0024 Gold Dial Metallic Chain Analog Watch for Men and Boys  ',
#   'price': '389',
#   'rating': '5.0',
#   'oprice': '₹389'},
#  {'brand': 'CLOUDWOOD',
#   'title': 'Digital Vintage Square Dial Unisex Wrist Watch for Men & Women -W70  ',
#   'price': '299',
#   'rating': '4.0',
#   'oprice': '₹299'},
#  {'brand': 'SWISSTYLE',
#   'title': 'Black Dial Blue Strap Analog Watch - for Men-SS-GR6622-BLU-BLU  ',
#   'price': '149',
#   'rating': '5.0',
#   'oprice': '₹149'},
#  {'brand': 'RITS ENTERPRISE',
#   'title': 'Analog Silvers and Coppers Diamond Combo Watches for Women and Girls  ',
#   'price': '299',
#   'rating': '5.0',
#   'oprice': '₹299'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Noise',
#   'title': 'Noise ColorFit Pulse Grand Smart Watch with 1.69"(42.9cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, Stress, Sleep, Heart Rate Monitoring & IP68 Waterproof (Champagne Grey)  ',
#   'price': '1,299',
#   'rating': '4.0',
#   'oprice': '₹1,299'},
#  {'brand': 'boAt',
#   'title': 'boAt Wave Prime47 Smart Watch with 1.69" HD Display, 700+ Active Modes, ASAP Charge, Live Cricket Scores, Crest App Health Ecosystem, HR & SpO2 Monitoring(Forest Green)  ',
#   'price': '1,199',
#   'rating': '3.4',
#   'oprice': '₹1,199'},
#  {'brand': 'Tokdis',
#   'title': 'Tokdis MX-1 Pro Bluetooth Calling Smartwatch - 1.69” LCD Display, Multiple Watch Faces, Sleep Monitor, Heart & SpO2 Monitoring, Multiple Sports Modes  ',
#   'price': '799',
#   'rating': '3.1',
#   'oprice': '₹799'},
#  {'brand': 'Hammer',
#   'title': 'Hammer Ace 3.0 Bluetooth Calling Smart Watch with Largest 1.85" IPS Display, Dual Mode, Spo2, Heart Rate, Strong Metallic Body & Skin Friendly Strap (Black)  ',
#   'price': '1,799',
#   'rating': '4.4',
#   'oprice': '₹1,799'},
#  {'brand': 'LOUIS DEVIN',
#   'title': 'Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054  ',
#   'price': '399',
#   'rating': '4.0',
#   'oprice': '₹399'},
#  {'brand': 'Shocknshop',
#   'title': 'Digital Sports Multi Functional Black Dial Watch for Mens Boys -315RED  ',
#   'price': '284',
#   'rating': '3.8',
#   'oprice': '₹284'},
#  {'brand': 'Generic',
#   'title': 'SHREENOVA® ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)  ',
#   'price': '278',
#   'rating': '3.2',
#   'oprice': '₹278'},
#  {'brand': 'TIMEX',
#   'title': "Analog Men's Watch  ",
#   'price': '849',
#   'rating': 'Shop coveted styles with many reviews',
#   'oprice': '₹849'},
#  {'brand': 'TIMEX',
#   'title': "Analog Men's Watch  ",
#   'price': '849',
#   'rating': '4.1',
#   'oprice': '₹849'},
#  {'brand': 'Fastrack',
#   'title': "Analog Dial Women's Watch (Pink, 6150SM04)-NM6150SM04 / NL6150SM04/NP6150SM04  ",
#   'price': '1,795',
#   'rating': '4.4',
#   'oprice': '₹1,795'},
#  {'brand': 'SWISSTONE',
#   'title': "Analog Women's Watch (Pink Dial Silver Colored Strap)  ",
#   'price': '326',
#   'rating': '4.1',
#   'oprice': '₹326'},
#  {'brand': 'SF',
#   'title': "Sporty Analog Black Dial Men's Watch-NL7930PP01/NP7930PP01  ",
#   'price': '625',
#   'rating': '4.0',
#   'oprice': '₹625'},
#  {'brand': 'TIMEX',
#   'title': "Analog Women's Watch (Dial Colored Strap)  ",
#   'price': '2,032',
#   'rating': '4.4',
#   'oprice': '₹2,032'},
#  {'brand': 'Casio',
#   'title': 'Youth Series Digital Black Dial Unisex Watch - F-91W-1Q(D002)  ',
#   'price': '1,095',
#   'rating': '4.4',
#   'oprice': '₹1,095'},
#  {'brand': 'SF',
#   'title': "Venus Digital Grey Dial Men's Watch-NL7982PP04/NM7982PP04  ",
#   'price': '499',
#   'rating': '4.1',
#   'oprice': '₹499'},
#  {'brand': 'Fastrack',
#   'title': "Casual Analog White Dial Men's Watch NM3114PP01/NN3114PP01/NP3114PP01  ",
#   'price': '1,095',
#   'rating': '4.1',
#   'oprice': '₹1,095'},
#  {'brand': 'Premium Wrist Watches for Men',
#   'title': "Chronograph Men's Watch (Black Dial)  ",
#   'price': '17,495',
#   'rating': 'Written by',
#   'oprice': '₹17,495'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Bouncefit',
#   'title': 'Bouncefit Fitness Band Smart Watch- Y68 D20 Water Proof Smart Watches SpO2 Full Touch Smartwatch with Workout Modes, Heart Rate Tracking, Sports Smart Watch for All Boys & Girls & Women - Jet Black  ',
#   'price': '480',
#   'rating': '3.3',
#   'oprice': '₹480'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'OnePlus',
#   'title': 'OnePlus Nord Watch with 1.78” AMOLED Display, 60 Hz Refresh Rate, 105 Fitness Modes, 10 Days Battery, SPO2, Heart Rate, Stress Monitor, Women Health Tracker & Multiple Watch Faces [Deep Blue]  ',
#   'price': '4,999',
#   'rating': '3.9',
#   'oprice': '₹4,999'},
#  {'brand': 'boAt',
#   'title': 'boAt Flash Edition Smart Watch with Activity Tracker, Multiple Sports Modes, 1.3" Screen, 170+ Watch Faces, Sleep Monitor, Gesture, Camera & Music Control, IP68 & 7 Days Battery Life(Galaxy Blue)  ',
#   'price': '1,199',
#   'rating': '4.0',
#   'oprice': '₹1,199'},
#  {'brand': 'LOCREST',
#   'title': 'Smart Watch for men women boys 1.3" OLED HD Display, Multiple watch Faces, SpO2 Monitoring, Sleep Monitor for Boys, Girls, Mens, Women & Kids for all Smartphones (ID 116 Plus Black) (ID116 Black)  ',
#   'price': '419',
#   'rating': '4.6',
#   'oprice': '₹419'},
#  {'brand': 'ADAMO',
#   'title': "Digital 24 Images Projector Watch for Kids Boys Watch, Diwali Gift, Birthday Return Gift, Best Digital Toy Watch for Boy's & Girl's BG-906  ",
#   'price': '289',
#   'rating': '4.1',
#   'oprice': '₹289'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'Acnos',
#   'title': "Digital Watch Shockproof Multi-Functional Automatic Black Color Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys Watch for Men Pack of 1 Watch Water Resistance Digital Watch  ",
#   'price': '280',
#   'rating': '3.9',
#   'oprice': '₹280'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Gladiator 1.96" Biggest Display Smart Watch with Bluetooth Calling, Voice Assistant &123 Sports Modes, 8 Unique UI Interactions, SpO2, 24/7 Heart Rate Tracking, Rs 100 Off on UPI  ',
#   'price': '2,499',
#   'rating': '4.0',
#   'oprice': '₹2,499'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Gladiator 1.96" Biggest Display Smart Watch with Bluetooth Calling, Voice Assistant &123 Sports Modes, 8 Unique UI Interactions, SpO2, 24/7 Heart Rate Tracking, Rs 100 Off on UPI  ',
#   'price': '2,499',
#   'rating': '4.0',
#   'oprice': '₹2,499'},
#  {'brand': 'VMBS',
#   'title': 'VMBS A1 Smart Watch Mobile Inbuild Camera Supporting 4G/5G Sim Smartwatch for Phone  ',
#   'price': '990',
#   'rating': '2.1',
#   'oprice': '₹990'},
#  {'brand': 'Matrix',
#   'title': 'Analog Day & Date Display Wrist Watch for Men & Boys (Black)  ',
#   'price': '299',
#   'rating': '3.6',
#   'oprice': '₹299'},
#  {'brand': 'Noise',
#   'title': 'NoiseFit Force Rugged Round Dial Bluetooth Calling Smart Watch with 1.32" HD screen, Functional Crown, 550 NITS, 7 days battery, AI Voice Assistance, 200+ Watch Faces, Heart Rate Tracker- (Teal Green)  ',
#   'price': '2,999',
#   'rating': '4.0',
#   'oprice': '₹2,999'},
#  {'brand': 'Shocknshop',
#   'title': 'Simple Sport Digital Men’s Military Watches Electronic LED Time Black Wrist Watch  ',
#   'price': '449',
#   'rating': '3.8',
#   'oprice': '₹449'},
#  {'brand': 'Shocknshop',
#   'title': "Stainless Steel Watch Series Analogue Men's Watch (Black Dial Mens Long Colored Strap) -W219  ",
#   'price': '285',
#   'rating': '3.8',
#   'oprice': '₹285'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Blue Dial Blue Colored Strap)  ",
#   'price': '266',
#   'rating': '3.6',
#   'oprice': '₹266'},
#  {'brand': 'hamt',
#   'title': "Analog Men's Watch (Multicolor Dial Multi Colored Strap)  ",
#   'price': '129',
#   'rating': '3.2',
#   'oprice': '₹129'},
#  {'brand': 'V2A',
#   'title': "Analogue - Digital Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '799',
#   'rating': '3.8',
#   'oprice': '₹799'},
#  {'brand': 'SWISSTONE',
#   'title': "Analog Men's Watch (Brown Dial Brown Colored Strap)  ",
#   'price': '299',
#   'rating': '3.6',
#   'oprice': '₹299'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Analogue Multi Color Dial Kids Watch for Boys and Girls - Combo of 2 Watches  ',
#   'price': '249',
#   'rating': '3.5',
#   'oprice': '₹249'},
#  {'brand': 'TIMEX',
#   'title': "Analog Black Dial Men's Watch-TW000U914  ",
#   'price': '2,499',
#   'rating': '4.4',
#   'oprice': '₹2,499'},
#  {'brand': 'Sylvi',
#   'title': "Premium Casual Stylish Watch | Luxury Working Chronograph Watch for Men | Water-Resistant Branded Men's Wrist Watch with Stopwatch & Date Display - Timegrapher Red Leather Watch  ",
#   'price': '1,109',
#   'rating': '3.3',
#   'oprice': '₹1,109'},
#  {'brand': 'Tommy Hilfiger',
#   'title': "Analog Blue Dial Men's Watch-TH1791474  ",
#   'price': '8,625',
#   'rating': '4.5',
#   'oprice': '₹8,625'},
#  {'brand': 'SELLORIA',
#   'title': 'Digital Watch Shockproof Multi-Functional Automatic Black Color Strap Waterproof Digital Sports Watch for Mens Kids Watch for Boys Watch for Men Pack of 1 Watch Water Resistance Digital Watch  ',
#   'price': '188',
#   'rating': '3.8',
#   'oprice': '₹188'},
#  {'brand': 'Drawya',
#   'title': 'Smart Watch D20 Y68 Smart Watch for Girls Boys Men Women Kids, Blacktooth 1.3" Smart Watch LED with Daily Activity Tracker, Heart Rate Sensor, for All Boys & Girls SmartWatch- Pink  ',
#   'price': '499',
#   'rating': '2.0',
#   'oprice': '₹499'},
#  {'brand': 'SWISSTYLE',
#   'title': "Analogue Black Dial Men's Watch - SS-GR918-BLK-BLK  ",
#   'price': '149',
#   'rating': '2.5',
#   'oprice': '₹149'},
#  {'brand': 'Generic',
#   'title': 'SHREENOVA XA Smart Watch for Men & Women Latest Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor,Sports Gym Watch for All Boys & Girls - Black  ',
#   'price': '295',
#   'rating': '3.0',
#   'oprice': '₹295'},
#  {'brand': 'Acnos',
#   'title': 'Black Dial Analogue Watch for Men Pack of 1 (FULLBLKPAYDU)  ',
#   'price': '265',
#   'rating': '3.5',
#   'oprice': '₹265'},
#  {'brand': 'MAGBOT',
#   'title': 'MAGBOT Q9 Smart Watch for Men & Women Latest Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor, BP Monitor, Sports Gym Watch for All Boys & Girls - Black  ',
#   'price': '499',
#   'rating': '3.7',
#   'oprice': '₹499'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Multi Dial Square 6 Crono Stylish Latest Generation Designer Rubber Strap Analog Watch - for Boys & Girls  ',
#   'price': '189',
#   'rating': '3.4',
#   'oprice': '₹189'},
#  {'brand': 'AYL',
#   'title': 'AYL Waterproof D-20 Touch Screen Smart Watch Bluetooth Smartwatch with Blood Pressure Tracking, Heart Rate Sensor and Basic Functionality for All Women and Girls (Pink)  ',
#   'price': '470',
#   'rating': '3.4',
#   'oprice': '₹470'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Multi Dial Chronograph Luxury Quartz Analog Watch for Men  ',
#   'price': '339',
#   'rating': '3.8',
#   'oprice': '₹339'},
#  {'brand': 'Mobivax',
#   'title': 'Smart Watch for Men Women ID116 Plus Smart Bracelet Fitness Tracker Color Screen Smartwatch Heart Rate Blood Pressure Pedometer Sleep Monitor  ',
#   'price': '399',
#   'rating': '4.5',
#   'oprice': '₹399'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch Series 8 [GPS 45 mm] Smart Watch w/Midnight Aluminium Case with Midnight Sport Band. Fitness Tracker, Blood Oxygen & ECG Apps, Always-On Retina Display, Water Resistant  ',
#   'price': '45,400',
#   'rating': '4.6',
#   'oprice': '₹45,400'},
#  {'brand': 'FORSINING',
#   'title': "Analogue Men's Watch(Gold Dial Silver Colored Strap)-S1089-2  ",
#   'price': '4,099',
#   'rating': '4.0',
#   'oprice': '₹4,099'},
#  {'brand': 'DIZO',
#   'title': 'DIZO Watch D2 Power (by realme TechLife) –Large 1.91" Superlight, Single Chipset Bluetooth Calling Smartwatch with Smart Swipe,150 +Stylish Watch Faces and 10 Day Battery (Classic Black)  ',
#   'price': '1,799',
#   'rating': '3.7',
#   'oprice': '₹1,799'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Square Multi DIAL Analog Silicon Strap ADDI Stylish Designer Analog Watch - for Boys  ',
#   'price': '189',
#   'rating': '3.5',
#   'oprice': '₹189'},
#  {'brand': 'Noise',
#   'title': 'Noise ColorFit Pulse Grand Smart Watch with 1.69"(4.2cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, Stress, Sleep, Heart Rate Monitoring & IP68 Waterproof (Lime Green)  ',
#   'price': '1,499',
#   'rating': '4.0',
#   'oprice': '₹1,499'},
#  {'brand': 'Audrey Brice',
#   'title': 'The Watch (Fourteen Tales of Thirteen Covens Book 5)  ',
#   'price': '0',
#   'rating': '5.0',
#   'oprice': '₹0'},
#  {'brand': 'pTron',
#   'title': 'pTron Force X12S Bluetooth Calling Smartwatch, 1.85" Full Touch HD Display, Functional Crown, Real Heart Rate Monitor, SpO2, Watch Faces, 5 Days Battery Life, Fitness Trackers & IP68 Waterproof (Pink)  ',
#   'price': '1,549',
#   'rating': '3.3',
#   'oprice': '₹1,549'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'The Classique - Black - Premium & Luxurious Watch for Men  ',
#   'price': '2,099',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,099'},
#  {'brand': 'FASHOKART',
#   'title': "Men's Military Watches Outdoor Sports Digital Watch Waterproof LED Date Alarm Wrist Watches for Men 8007 Dark Green  ",
#   'price': '989',
#   'rating': 'New to Amazon',
#   'oprice': '₹989'},
#  {'brand': 'FASHOKART',
#   'title': "Men's Military Watches Outdoor Sports Digital Watch Waterproof LED Date Alarm Wrist Watches for Men 8007 Green  ",
#   'price': '989',
#   'rating': 'New to Amazon',
#   'oprice': '₹989'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'The Classique - Green - Premium & Luxurious Watch for Men  ',
#   'price': '2,099',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,099'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and colour.',
#   'oprice': None},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'GOLDENIZE FASHION',
#   'title': 'Goldenize Fashion Multicolor Digital Dial Waterproof Stylish and Fashion Child Wrist Smart Watch LED Band for Kids,Colorful 3D Cartoon Super Hero for Kids,Boys & Girls (Pink Mouse-White Doremon)  ',
#   'price': '369',
#   'rating': 'New to Amazon',
#   'oprice': '₹369'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'FORSINING',
#   'title': "Analogue Men's Watch(Gold Dial Silver Colored Strap)-S1089-2  ",
#   'price': '4,099',
#   'rating': '4.0',
#   'oprice': '₹4,099'},
#  {'brand': 'Generic',
#   'title': 'New Edition i7 Pro Max All in One Series 7 Smart Watch with Fitness Tracker Heart Monitor Men Women Smart Watch Black  ',
#   'price': '599',
#   'rating': '3.3',
#   'oprice': '₹599'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Analog Unique Arrow Black Silicon Strap Watch for Men and Boys  ',
#   'price': '249',
#   'rating': '3.5',
#   'oprice': '₹249'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'boAt',
#   'title': 'boAt Wave Lite Smartwatch with 1.69 Inches(4.29cm) HD Display, Heart Rate & SpO2 Level Monitor, Multiple Watch Faces, Activity Tracker, Multiple Sports Modes & IP68 (Scarlet Red)  ',
#   'price': '1,499',
#   'rating': '3.9',
#   'oprice': '₹1,499'},
#  {'brand': 'BENYAR',
#   'title': 'Wrist Watches for Men Leather Strap Analog Chronograph Fashion Business Sport Design Mens Watch 30M Waterproof Stylish Elegant Gifts for Men  ',
#   'price': '2,890',
#   'rating': '4.1',
#   'oprice': '₹2,890'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch SE (2nd Gen) [GPS 44 mm] Smart Watch w/Midnight Aluminium Case & Midnight Sport Band. Fitness & Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant  ',
#   'price': '31,900',
#   'rating': '4.6',
#   'oprice': '₹31,900'},
#  {'brand': 'OLICOM',
#   'title': 'OLICOM M1 Smart Watch Id-116 Bluetooth Smartwatch Wireless Fitness Band for Boys, Girls, Men, Women & Kids | Sports Gym Watch for All Smart Phones I Heart Rate and spo2 Monitor  ',
#   'price': '499',
#   'rating': '3.6',
#   'oprice': '₹499'},
#  {'brand': 'NAVIFORCE',
#   'title': "Men's Military Digital Watches Analog Quartz Waterproof Watch Sport Multifunctional Leather Wristwatch  ",
#   'price': '2,994.',
#   'rating': '4.5',
#   'oprice': '₹2,994.40'},
#  {'brand': 'DIZO',
#   'title': 'DIZO Watch D2 Power (by realme TechLife) – Large 1.91" Superlight, Single Chipset Bluetooth Calling Smartwatch with Smart Swipe, 150+Stylish Watch Faces and 10 Day Battery (Steel Grey)  ',
#   'price': '1,799',
#   'rating': '3.7',
#   'oprice': '₹1,799'},
#  {'brand': 'FANMIS',
#   'title': 'Unisex Elegant Plane Style Digital Display Waterproof Outdoor Sports Silicone Strap LED Wrist Watch ( black )  ',
#   'price': '390',
#   'rating': '3.4',
#   'oprice': '₹390'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'AYL',
#   'title': 'AYL Smart Watch New Generation for You ID116 Touchscreen Android Smart Watch Bluetooth Smartwatch with Heart Rate Sensor and Basic Functionality for All Women, Men, Boys & Girls - Black  ',
#   'price': '499',
#   'rating': '3.4',
#   'oprice': '₹499'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Multi Dial Square 6 Crono Stylish Latest Generation Designer Rubber Strap Analog Watch - for Boys & Girls  ',
#   'price': '189',
#   'rating': '3.4',
#   'oprice': '₹189'},
#  {'brand': 'boAt',
#   'title': 'boAt Xtend Smart Watch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, HR & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor, 5 ATM & 7 Days Battery Life(Deep Blue)  ',
#   'price': '1,799',
#   'rating': '4.2',
#   'oprice': '₹1,799'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Analogue Multi Color Dial Kids Watch for Boys & Girls  ',
#   'price': '249',
#   'rating': '3.3',
#   'oprice': '₹249'},
#  {'brand': 'VYL',
#   'title': 'Smart watch New Launch Smart Watches ID116 Bluetooth Smartwatch Wireless Fitness Band for Boys, Girls, Men, Women & Kids | Sports Gym Watch for All Smart Phones I Heart Rate and spo2 Monitor - (Black)  ',
#   'price': '499',
#   'rating': '2.7',
#   'oprice': '₹499'},
#  {'brand': 'V2A',
#   'title': "Analog-Digital Men's Watch (Black Dial Black Colored Strap)  ",
#   'price': '990',
#   'rating': '4.1',
#   'oprice': '₹990'},
#  {'brand': 'A',
#   'title': 'Acnos Brand 3 Color Watch with Black PU Strap Watch M2 Digital for Mens and Watches for Boy Pack of-2  ',
#   'price': '284',
#   'rating': '3.5',
#   'oprice': '₹284'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Black Dial Colored Strap)  ",
#   'price': '319',
#   'rating': '4.2',
#   'oprice': '₹319'},
#  {'brand': 'PAPIO',
#   'title': "Digital Men's Watch (Black Dial Multi Colored Strap)  ",
#   'price': '449',
#   'rating': '3.7',
#   'oprice': '₹449'},
#  {'brand': 'Sylvi',
#   'title': "Multi-Functional Boys Casual Business Mens Luxury Stylish Watch Black Dial Leather Strap Wrist Watches for Men-Daily Use Analog Digital Sports Men's Watch  ",
#   'price': '986',
#   'rating': '3.9',
#   'oprice': '₹986'},
#  {'brand': 'Fastrack',
#   'title': 'Fastrack Reflex Hello Smart Watch with BT Calling|Bright HD Display|AI Voice Assistant|50+ Sports Modes|100+ Watchfaces|BP Monitor|24x7 HRM| SpO2|Upto 5 Day Battery|Camera & Music Control|IP68  ',
#   'price': '3,995',
#   'rating': '3.8',
#   'oprice': '₹3,995'},
#  {'brand': 'REDUX',
#   'title': "Analog Boy's & Men's Watch (Brown Dial Colored Strap)  ",
#   'price': '265',
#   'rating': '3.4',
#   'oprice': '₹265'},
#  {'brand': 'Hammer',
#   'title': 'Hammer Pulse Ace Pro Bluetooth Calling Smartwatch with SpO2 & 1.81” Aluminium Alloy Body with Blood Oxygen Monitoring, Heart Rate, Full Touch & Multiple Watch Faces with Customization (Black)  ',
#   'price': '1,798',
#   'rating': '3.8',
#   'oprice': '₹1,798'},
#  {'brand': 'Sonata',
#   'title': 'Analog Watches for Men  ',
#   'price': '899',
#   'rating': '4.3',
#   'oprice': '₹899'},
#  {'brand': 'BITZAG',
#   'title': 'New LED Watch for Boys, Girls and Kids Digital Black Dial Led Watch for Kids Unisex Birthday Gift Digital Watch  ',
#   'price': '100',
#   'rating': '3.9',
#   'oprice': '₹100'},
#  {'brand': 'VILLS LAURRENS',
#   'title': '9951 Pure Black Chain Day & Date Wrist Watch Original Black Watch Analog Watch - for Men  ',
#   'price': '399',
#   'rating': '3.0',
#   'oprice': '₹399'},
#  {'brand': 'CrossBeats',
#   'title': 'CrossBeats Ignite S5 Advanced AI ENC BT Calling Smartwatch, 1.96” Super AMOLED Anti-Glare Screen, Always on Display, Calculator, 500+ Watch Faces, 360 Degree Health Tracking, Fast Charge (Silver)  ',
#   'price': '4,499',
#   'rating': '4.1',
#   'oprice': '₹4,499'},
#  {'brand': 'FRIEDRICH',
#   'title': "Analogue White Dial Spiderman Boy's, Girl's Watch (Red)  ",
#   'price': '249',
#   'rating': '3.7',
#   'oprice': '₹249'},
#  {'brand': 'Fastrack',
#   'title': 'New Fastrack Reflex Beat+ 1.69” UltraVU Display|500 Nits Brightness|60 Sports Modes|24*7 Heart Rate Monitor|SpO2 Monitor|Sleep Tracker|IP68 Water Resistant|Music & Camera Control  ',
#   'price': '1,695',
#   'rating': '4.0',
#   'oprice': '₹1,695'},
#  {'brand': 'CERO',
#   'title': "Digital Dial Men's & Women's Watch(AB206-VSD)  ",
#   'price': '299',
#   'rating': '2.5',
#   'oprice': '₹299'},
#  {'brand': None,
#   'title': 'Maxima Max Pro X4+ Rugged Bluetooth Calling Smart Watch 1.32" Round Always on Premium Display with 360x360 px Resolution, AI Voice Assitant, Advance UI, 340 mah Big Battery, HR/SpO2, 150+ Watch Faces  ',
#   'price': '2,400',
#   'rating': '3.7',
#   'oprice': '₹2,400'},
#  {'brand': 'RUSTET',
#   'title': 'Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054  ',
#   'price': '349',
#   'rating': '3.9',
#   'oprice': '₹349'},
#  {'brand': 'sunway',
#   'title': "sunway M3 Silicone LED Digital Black Men's Women's Watch  ",
#   'price': '148',
#   'rating': '2.8',
#   'oprice': '₹148'},
#  {'brand': 'The Shopoholic',
#   'title': 'Analog Dial Black Metal Strap Watch Series Watches for Men Watch for Man and Watch for Boys  ',
#   'price': '284',
#   'rating': '3.5',
#   'oprice': '₹284'},
#  {'brand': 'Casio',
#   'title': "Formal Analog White Dial Men's Watch-MTP-V300L-7AUDF (A1177)  ",
#   'price': '3,795',
#   'rating': '4.2',
#   'oprice': '₹3,795'},
#  {'brand': 'Acnos',
#   'title': 'Special Super Quality Analog Watches Combo Look Like Handsome for Boys and Mens Pack of - 3(STL-437-436)  ',
#   'price': '535',
#   'rating': '3.6',
#   'oprice': '₹535'},
#  {'brand': 'boAt',
#   'title': 'boAt Matrix Smart Watch with 1.65” AMOLED Display, Always On Mode, Slim Premium Design, Heart Rate & SpO2 Monitoring, Health Ecosystem & Multiple Sports Modes, 3ATM & 7 Days Battery Life(Pitch Black)  ',
#   'price': '1,499',
#   'rating': '3.9',
#   'oprice': '₹1,499'},
#  {'brand': 'SKMEI',
#   'title': "Men's Digital Sports Watch, LED Square Large Face Analog Quartz Wrist Watch with Multi-Time Zone Waterproof Stopwatch - 1834/1835  ",
#   'price': '839',
#   'rating': '3.9',
#   'oprice': '₹839'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ring Bluetooth Calling Smartwatch with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (Grey)  ',
#   'price': '2,299',
#   'rating': '4.1',
#   'oprice': '₹2,299'},
#  {'brand': 'pTron',
#   'title': 'PTron Newly Launched Force X10 Bluetooth Calling Smartwatch with 1.7" Full Touch Color Display, Real Heart Rate Monitor, SpO2, Watch Faces, 5 Days Runtime, Fitness Trackers & IP68 Waterproof (Pink)  ',
#   'price': '1,499',
#   'rating': '3.2',
#   'oprice': '₹1,499'},
#  {'brand': 'RPS FASHION WITH DEVICE OF R',
#   'title': "Quartz Movement Analogue Display Multicoloured Dial Men's Watch (Green Dial Green Colored Strap)-Army  ",
#   'price': '125',
#   'rating': '3.3',
#   'oprice': '₹125'},
#  {'brand': 'ADAMO',
#   'title': "Digital 24 Images Projector Watch for Kids Boys Watch, Diwali Gift, Birthday Return Gift, Best Digital Toy Watch for Boy's & Girl's BG-906  ",
#   'price': '289',
#   'rating': '4.1',
#   'oprice': '₹289'},
#  {'brand': 'NIBOSI',
#   'title': "Men's Watches Luxury Fashion Casual Dress Chronograph Waterproof Military Quartz Wristwatches for Men Stainless Steel Band  ",
#   'price': '2,290',
#   'rating': '3.8',
#   'oprice': '₹2,290'},
#  {'brand': 'CrossBeats',
#   'title': 'CrossBeats Ignite GRIT Smart Watch, 1.83 AMOLED Display with Advanced Bluetooth Calling, Rotating Crown,AI Health Sensors, 150+ Sports Modes, 250+Watch Faces, in-Built Games, 15 Days Battery-Pink  ',
#   'price': '2,799',
#   'rating': '4.3',
#   'oprice': '₹2,799'},
#  {'brand': 'Amazon Renewed',
#   'title': '(Renewed) Mi Watch Revolve Active (Black)- SpO2 and Sleep Monitor, 1.39" AMOLED Display, 2 Weeks Battery Life, Alexa Built-in, 117 Sports Mode, GPS  ',
#   'price': '6,462',
#   'rating': '3.7',
#   'oprice': '₹6,462'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Avenger Black Dial Watch for Men & Boys  ',
#   'price': '189',
#   'rating': '3.4',
#   'oprice': '₹189'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ninja 3 1.83" Display Smartwatch Full Touch with 100+ Sports Modes with IP68, Sp02 Tracking, Over 100 Cloud Based Watch Faces  ',
#   'price': '1,299',
#   'rating': '4.2',
#   'oprice': '₹1,299'},
#  {'brand': 'LS LAPSTER Quality Assured',
#   'title': 'Lapster USB all types smartwatch charger cable for boat watch charger & boat xtend watch charger & boat storm watch charger- All 2 Pin Watch (Cable Only)  ',
#   'price': '113',
#   'rating': '3.4',
#   'oprice': '₹113'},
#  {'brand': 'REDUX',
#   'title': "RWS0178S Analogue Silver Dial Men's & Boy's Watch  ",
#   'price': '185',
#   'rating': '3.7',
#   'oprice': '₹185'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch Ultra [GPS + Cellular 49 mm] Smart Watch w/Rugged Titanium Case & White Ocean Band. Fitness Tracker, Precision GPS, Action Button, Extra-Long BatteryLife, Brighter Retina Display  ',
#   'price': '89,899',
#   'rating': '4.2',
#   'oprice': '₹89,899'},
#  {'brand': 'FROZIL',
#   'title': "Digital Watch Shockproof Multi-Functional Automatic Full Black Color Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys Watch for Men Pack of-1  ",
#   'price': '280',
#   'rating': '3.7',
#   'oprice': '₹280'},
#  {'brand': 'APCSA',
#   'title': 'APCSA Original New Series 7 D20 Bluetooth Wireless Smart Watch, Fitness Band for Boys, Girls, Men, Women & Kids | Sports Watch for All Smart Phones I Heart Rate and BP Monitor ( Pink )  ',
#   'price': '499',
#   'rating': '3.3',
#   'oprice': '₹499'},
#  {'brand': 'Emartos',
#   'title': 'Black Dial Arrow Analog Watch with King Bracelet for Men (Pack of 2)  ',
#   'price': '429',
#   'rating': '3.1',
#   'oprice': '₹429'},
#  {'brand': 'PAPIO',
#   'title': "PU Belt Analogue Men's Watch and Boy's Watch  ",
#   'price': '199',
#   'rating': '4.7',
#   'oprice': '₹199'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'TIMEX',
#   'title': "Analog Black Dial Men's Watch-TW000U934  ",
#   'price': '1,299',
#   'rating': '4.2',
#   'oprice': '₹1,299'},
#  {'brand': 'Fastrack',
#   'title': "Analog Purple Dial Women's Watch-6282SL02  ",
#   'price': '1,495',
#   'rating': '4.5',
#   'oprice': '₹1,495'},
#  {'brand': 'Noise',
#   'title': 'Noise ColorFit Ultra Buzz Bluetooth Calling Smart Watch with 1.75" HD Display, 320x385 px Resolution, 100 Sports Modes, Stock Market Info Smartwatch for Men & Women (Champagne Grey)  ',
#   'price': '1,999',
#   'rating': '4.1',
#   'oprice': '₹1,999'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Amanda Witt',
#   'title': 'The Watch (Red Book 1)  ',
#   'price': '446',
#   'rating': '4.7',
#   'oprice': '₹446'},
#  {'brand': 'Generic',
#   'title': 'Waterproof D20 Touchscreen Smart Watch Bluetooth Smartwatch with Blood Pressure Tracking, Heart Rate Sensor and Basic Functionality for All Women and Men  ',
#   'price': '332',
#   'rating': '2.5',
#   'oprice': '₹332'},
#  {'brand': 'Diesel',
#   'title': 'Unisex 44mm Master Chief Silicone Sport Digital Watch, Color: White (Model: DZ2157), White, One Size, Master Chief Digital Silicone Watch - DZ2157  ',
#   'price': '13,995',
#   'rating': None,
#   'oprice': '₹13,995'},
#  {'brand': 'Generic',
#   'title': 'i8 Pro Max Touch Screen Bluetooth Smartwatch with Activity Tracker Compatible with All 3G/4G/5G Android & iOS Smartphones - Black  ',
#   'price': '919',
#   'rating': '2.9',
#   'oprice': '₹919'},
#  {'brand': 'Apple',
#   'title': 'Apple Watch SE (2nd Gen) [GPS 40 mm] Smart Watch w/Midnight Aluminium Case & Midnight Sport Band. Fitness & Sleep Tracker, Crash Detection, Heart Rate Monitor, Retina Display, Water Resistant  ',
#   'price': '29,003',
#   'rating': '4.6',
#   'oprice': '₹29,003'},
#  {'brand': 'Fastrack',
#   'title': "Analog Black Dial Men's Watch-NG38022PP03W / NG38022PP03C  ",
#   'price': '795',
#   'rating': '4.4',
#   'oprice': '₹795'},
#  {'brand': 'Bulova',
#   'title': "Men's Precisionist X 10th Anniversary Rose Gold Stainless Steel and Demascus Steel 8-Hand Chronograph Watch with Brown Leather Strap and Sapphire Crystal Style: 98B356  ",
#   'price': '2,13,391',
#   'rating': '4.9',
#   'oprice': '₹2,13,391'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Sonata',
#   'title': "Super Fibre Digital Grey Dial Men's Watch-NL87011PP04/NP87011PP04  ",
#   'price': '600',
#   'rating': '4.2',
#   'oprice': '₹600'},
#  {'brand': 'SKMEI',
#   'title': "Men's Digital Sports Watch, Waterproof LED Screen Large Face Military Watches and Heavy Duty Electronic Simple Army Watch with Alarm - 1820  ",
#   'price': '799',
#   'rating': '4.0',
#   'oprice': '₹799'},
#  {'brand': 'Sonata',
#   'title': "Beyond Gold Analog Black Dial Men's Watch-NN77031KM03/NP77031KM03  ",
#   'price': '2,149',
#   'rating': '4.3',
#   'oprice': '₹2,149'},
#  {'brand': 'SKMEI',
#   'title': "Men's Digital Sports Wrist Watch LED Screen Large Face Electronics Military Watches Waterproof Alarm Stopwatch Back Light Outdoor Casual Black Watch  ",
#   'price': None,
#   'rating': '3.9',
#   'oprice': None},
#  {'brand': 'Redmi',
#   'title': "Redmi Watch 2 Lite - 3.94 cm Large HD Edge Display, Multi-System Standalone GPS, Continuous SpO2, Stress & Sleep Monitoring, 24x7 HR, 5ATM, 120+ Watch Faces, 100+ Sports Modes, Women's Health, Blue  ",
#   'price': '2,499',
#   'rating': '3.9',
#   'oprice': '₹2,499'},
#  {'brand': 'MARVIK',
#   'title': 'MARVIK Smart Watch D116 for Xiaomi Mi Note 9 Smart Watch Bluetooth SmartWatch with Activity Tracker, Heart Rate Sensor, Sleep Monitor and Basic Functionality for All Boys & Girls  ',
#   'price': '494',
#   'rating': '3.1',
#   'oprice': '₹494'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Black Dial Colored Strap)  ",
#   'price': '319',
#   'rating': '4.2',
#   'oprice': '₹319'},
#  {'brand': 'PAPIO',
#   'title': "Digital Men's Watch (Black Dial Multi Colored Strap)  ",
#   'price': '449',
#   'rating': '3.7',
#   'oprice': '₹449'},
#  {'brand': 'Sylvi',
#   'title': "Multi-Functional Boys Casual Business Mens Luxury Stylish Watch Black Dial Leather Strap Wrist Watches for Men-Daily Use Analog Digital Sports Men's Watch  ",
#   'price': '986',
#   'rating': '3.9',
#   'oprice': '₹986'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Analogue Watch for Men and Boys  ',
#   'price': '219',
#   'rating': '3.7',
#   'oprice': '₹219'},
#  {'brand': 'CrossBeats',
#   'title': 'CrossBeats Newly launched Ignite S5 Advanced AI ENC BT Calling Smartwatch, 1.96” Super AMOLED Anti-Glare Screen, Always on Display, SnapCharge™ Calculator, 500+ Watch Faces, AI Health Feature (Black)  ',
#   'price': '4,499',
#   'rating': '4.1',
#   'oprice': '₹4,499'},
#  {'brand': 'Acnos',
#   'title': "Luxury Analogue Girl's Watch(Multicolour Dial 1-Multicolour Colored Strap)  ",
#   'price': '385',
#   'rating': '3.9',
#   'oprice': '₹385'},
#  {'brand': 'SF',
#   'title': "Sporty Digital Grey Dial Men's Watch-NL77043PP02/NP77043PP02  ",
#   'price': '448',
#   'rating': '4.0',
#   'oprice': '₹448'},
#  {'brand': 'Fastrack',
#   'title': "Analog Rose Gold Dial Women's Watch-NM6147NM01 / NL6147NL01/NP6147NM01  ",
#   'price': '2,495',
#   'rating': '4.3',
#   'oprice': '₹2,495'},
#  {'brand': 'CYLECT',
#   'title': 'CYLECT Smart Watch for Men women - Smart Watches for Men Women, Bluetooth Smartwatch Touch Screen Bluetooth Smart Watches for Android iOS Phones Wrist Phone Watch, Women - pink  ',
#   'price': '598',
#   'rating': '3.8',
#   'oprice': '₹598'},
#  {'brand': 'Maicrogear',
#   'title': 'Unisex Swiss True High Tech Analogue Ceramic Watch (White)  ',
#   'price': '2,999',
#   'rating': 'M.R.P: ',
#   'oprice': '₹2,999'},
#  {'brand': 'Casio',
#   'title': "Edifice Analog Red Dial Men's Watch-EFR-526D-5CVUDF  ",
#   'price': '8,495',
#   'rating': None,
#   'oprice': '₹8,495'},
#  {'brand': 'Fossil',
#   'title': "Dean Chronograph Black Dial Men's Watch-FS4721  ",
#   'price': '8,636',
#   'rating': '4.2',
#   'oprice': '₹8,636'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Artistic Love Symbol Butterfly Red Analog Watch for Girls and Women Watch - for Girls  ',
#   'price': '189',
#   'rating': '3.3',
#   'oprice': '₹189'},
#  {'brand': 'jainx',
#   'title': 'Casual Analogue Women Watch (Blue Dial Silver Colored Chain)  ',
#   'price': '282',
#   'rating': '3.9',
#   'oprice': '₹282'},
#  {'brand': 'SENS',
#   'title': 'SENS NUTON 1 with 1.7 IPS Display, Orbiter, 5ATM & 150+ Watch Faces & Free Additional Strap (Royal Silver)  ',
#   'price': '1,099',
#   'rating': '3.9',
#   'oprice': '₹1,099'},
#  {'brand': 'pTron',
#   'title': 'PTron Newly Launched Force X11P Bluetooth Calling Smartwatch with 1.3" Full Touch Display, Heart Rate Tracking, SpO2, 100s of Watch Faces, 5 Days Runtime, Fitness Trackers & IP68 Waterproof (Black)  ',
#   'price': '1,299',
#   'rating': '3.4',
#   'oprice': '₹1,299'},
#  {'brand': 'NAVIFORCE',
#   'title': "Analog-Digital Men's Watch (Black Dial)  ",
#   'price': '2,351',
#   'rating': '4.1',
#   'oprice': '₹2,351'},
#  {'brand': 'Fastrack',
#   'title': 'Reflex Vox Smartwatch|Alexa Built-in|Bright HD Display|Upto 10 Days Battery|5 ATM Water Resistance|Multiple Sports Modes|100+ Watchfaces|24x7 HRM|Sp02|Stress Monitor|Camera & Music Control  ',
#   'price': '1,995',
#   'rating': '3.9',
#   'oprice': '₹1,995'},
#  {'brand': 'ZUPERIA',
#   'title': 'Diamond Studded Stylish Analogue Watch with Rose Gold Dot Bracelet for Girls & Women  ',
#   'price': '240',
#   'rating': '3.8',
#   'oprice': '₹240'},
#  {'brand': 'Fitbit',
#   'title': 'Fitbit FB507BKBK Versa 2 Health & Fitness Smartwatch with Heart Rate, Music, Alexa Built-in, Sleep & Swim Tracking, Black/Carbon, One Size (S & L Bands Included) (Black/Carbon)  ',
#   'price': '11,999',
#   'rating': '4.1',
#   'oprice': '₹11,999'},
#  {'brand': 'Fastrack',
#   'title': 'Analog Grey Dial Unisex-Adult Watch-68013PP10  ',
#   'price': '950',
#   'rating': '4.2',
#   'oprice': '₹950'},
#  {'brand': None,
#   'title': 'Maxima Max Pro X4+ Rugged Bluetooth Calling Smart Watch 1.32" Round Always on Premium Display with 360x360 px Resolution, AI Voice Assitant, Advance UI, 340 mah Big Battery, HR/SpO2, 150+ Watch Faces  ',
#   'price': '2,400',
#   'rating': '3.7',
#   'oprice': '₹2,400'},
#  {'brand': 'IIK COLLECTION',
#   'title': 'Watches for Women Stainless Steel Chain & Diamond Studded Dial Ladies Watch - Water Resistant Womens Watches  ',
#   'price': '399',
#   'rating': '4.1',
#   'oprice': '₹399'},
#  {'brand': 'Maxima',
#   'title': 'Newly Launched Maxima Max Pro Knight Bluetooth Calling smartwatch with 44.5mm Round Active Display of 550 Nits Brightness, Voice Assistant, HR & SpO2 Monitor,30+ Excercise Modes, inbuilt Games  ',
#   'price': '2,475',
#   'rating': '3.5',
#   'oprice': '₹2,475'},
#  {'brand': 'Armani Exchange',
#   'title': "Outerbanks Analog Black Dial Men's Watch-AX2520  ",
#   'price': '4,797',
#   'rating': '4.3',
#   'oprice': '₹4,797'},
#  {'brand': 'TIMEX',
#   'title': "Analog White Dial Men's Watch-TW000U933  ",
#   'price': '1,599',
#   'rating': '4.1',
#   'oprice': '₹1,599'},
#  {'brand': 'Sonata',
#   'title': "Analog Silver Dial Men's Watch-7142NL01  ",
#   'price': '1,099',
#   'rating': '3.3',
#   'oprice': '₹1,099'},
#  {'brand': 'Fire-Boltt',
#   'title': 'Fire-Boltt Ring Bluetooth Calling Smartwatch with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (Blue)  ',
#   'price': '2,299',
#   'rating': '4.1',
#   'oprice': '₹2,299'},
#  {'brand': 'V2A',
#   'title': 'Outdoor Sport Shockproof Led Analogue and Digital Waterproof Chronograph Watch for Men  ',
#   'price': '990',
#   'rating': '4.0',
#   'oprice': '₹990'},
#  {'brand': 'Fastrack',
#   'title': 'Analog Purple Dial Unisex-Adult Watch-9915PP97  ',
#   'price': '995',
#   'rating': '4.4',
#   'oprice': '₹995'},
#  {'brand': 'SF',
#   'title': "Venus Digital Grey Dial Men's Watch-NL7982PP01/NM7982PP01  ",
#   'price': '499',
#   'rating': '4.1',
#   'oprice': '₹499'},
#  {'brand': 'Casio',
#   'title': "Edifice Men's Tachymeter Chronograph EF-558SG-1AVDF (ED439)  ",
#   'price': '15,995',
#   'rating': '4.4',
#   'oprice': '₹15,995'},
#  {'brand': 'Fossil',
#   'title': "Analog Silver Dial Men's Watch-FS4991  ",
#   'price': '8,796',
#   'rating': '4.3',
#   'oprice': '₹8,796'},
#  {'brand': 'IMOO',
#   'title': 'IMOO Watch Phone Z1 Kids Smart Watch, 4G Kids Smartwatch Phone with Long-Lasting Video & Phone Call, Kids GPS Watch with Real-time Locating & IPX8 Water-Resistance (Pink)  ',
#   'price': '9,990',
#   'rating': '4.3',
#   'oprice': '₹9,990'},
#  {'brand': 'SF',
#   'title': "Economy Digital Multi-color Round Dial Men's Sport Watch-NN77006PP01/NP77006PP01  ",
#   'price': '748',
#   'rating': '3.9',
#   'oprice': '₹748'},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': 'Matrix',
#   'title': 'Black, Blue, White Dial, Day & Date Functioning, Stainless Steel Strap Analog Watch for Men & Women  ',
#   'price': '329',
#   'rating': '3.0',
#   'oprice': '₹329'},
#  {'brand': 'Acnos',
#   'title': "Digital Watch Shockproof Multi-Functional Automatic Black Color Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys Watch for Men Pack of 1 Watch Water Resistance Digital Watch  ",
#   'price': '280',
#   'rating': '3.9',
#   'oprice': '₹280'},
#  {'brand': 'PAPIO',
#   'title': "PU Belt Analogue Men's Watch and Boy's Watch  ",
#   'price': '199',
#   'rating': '4.7',
#   'oprice': '₹199'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': 'Price and other details may vary based on product size and colour.',
#   'oprice': None},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'A',
#   'title': 'Acnos Brand 3 Color Watch with Black PU Strap Watch M2 Digital for Mens and Watches for Boy Pack of-2  ',
#   'price': '284',
#   'rating': '3.5',
#   'oprice': '₹284'},
#  {'brand': 'pTron',
#   'title': 'pTron Force X12S Bluetooth Calling Smartwatch, 1.85" Full Touch HD Display, Functional Crown, Real Heart Rate Monitor, SpO2, WatchFaces, 5 Days Battery Life, Fitness Trackers & IP68 Waterproof (Black)  ',
#   'price': '1,199',
#   'rating': '3.7',
#   'oprice': '₹1,199'},
#  {'brand': 'Acnos',
#   'title': "Luxury Analogue Girl's Watch(Multicolour Dial 1-Multicolour Colored Strap)  ",
#   'price': '385',
#   'rating': '3.9',
#   'oprice': '₹385'},
#  {'brand': 'Adlynlife',
#   'title': 'Adlynlife 22mm Smart Watch Straps/Smart Watch Band Compatible for Realme Watch S/Realme S Pro (Black)  ',
#   'price': '289',
#   'rating': '4.5',
#   'oprice': '₹289'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Fastrack',
#   'title': "Analog Rose Gold Dial Women's Watch-NM6147NM01 / NL6147NL01/NP6147NM01  ",
#   'price': '2,495',
#   'rating': '4.3',
#   'oprice': '₹2,495'},
#  {'brand': 'Fitbit',
#   'title': 'Fitbit FB507RGPK Versa 2 Health & Fitness Smartwatch with Heart Rate, Music, Alexa Built-in, Sleep & Swim Tracking, Petal/Copper Rose, One Size (S & L Bands Included) (Petal/Copper Rose)  ',
#   'price': '11,999',
#   'rating': '4.1',
#   'oprice': '₹11,999'},
#  {'brand': 'Maicrogear',
#   'title': 'Unisex Swiss True High Tech Analogue Ceramic Watch (White)  ',
#   'price': '2,999',
#   'rating': 'New to Amazon',
#   'oprice': '₹2,999'},
#  {'brand': 'Casio',
#   'title': "Edifice Analog Red Dial Men's Watch-EFR-526D-5CVUDF  ",
#   'price': '8,495',
#   'rating': 'New to Amazon',
#   'oprice': '₹8,495'},
#  {'brand': 'Epaal',
#   'title': 'Epaal Case Compatible with Realme Watch 3 Pro Only, Anti Scratch Shockproof PC Case Cover Protector  ',
#   'price': '299',
#   'rating': 'No reviews',
#   'oprice': '₹299'},
#  {'brand': 'Keith Buckley',
#   'title': 'Watch: A Novel  ',
#   'price': '939.',
#   'rating': '4.6',
#   'oprice': '₹939.86'},
#  {'brand': 'SWADESI STUFF',
#   'title': 'Artistic Love Symbol Butterfly Red Analog Watch for Girls and Women Watch - for Girls  ',
#   'price': '189',
#   'rating': '3.3',
#   'oprice': '₹189'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'French Connection',
#   'title': "Smart Man Full Touch Smartwatch with Mesh Band (Color: Silver) with 1.69'' Large Display, Bluetooth, Sport Modes, Metal Body, Heart Rate Monitor, Multiple Watch Faces- E17-D  ",
#   'price': '4,800',
#   'rating': '3.1',
#   'oprice': '₹4,800'},
#  {'brand': 'French Connection',
#   'title': "Analog Dial Women's Watch  ",
#   'price': '2,415.',
#   'rating': '4.3',
#   'oprice': '₹2,415.49'},
#  {'brand': 'Casio',
# ...
#   'price': '245',
#   'rating': '3.4',
#   'oprice': '₹245'},
#  {'brand': 'Casio',
#   'title': "Analog Black Dial Men's Watch-MTP-VT01L-1BUDF (A1615)  ",
#   'price': '2,965',
#   'rating': '4.3',
#   'oprice': '₹2,965'},
#  {'brand': 'LS LAPSTER Quality Assured',
#   'title': 'Lapster USB all types smartwatch charger cable for boat watch charger & boat xtend watch charger & boat storm watch charger- All 2 Pin Watch (Cable Only)  ',
#   'price': '113',
#   'rating': '3.4',
#   'oprice': '₹113'},
#  {'brand': 'Fastrack',
#   'title': "Casual Analog Black Dial Women's Watch-6248NM01  ",
#   'price': '1,795',
#   'rating': '4.4',
#   'oprice': '₹1,795'},
#  {'brand': 'V2A',
#   'title': 'Outdoor Sport Shockproof Led Analogue and Digital Waterproof Chronograph Watch for Men  ',
#   'price': '990',
#   'rating': '4.0',
#   'oprice': '₹990'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Minute Track Dial Stainless Steel Chain Watch for Men  ',
#   'price': '279',
#   'rating': '3.9',
#   'oprice': '₹279'},
#  {'brand': 'Emartos',
#   'title': 'Black Dial Arrow Analog Watch with King Bracelet for Men (Pack of 2)  ',
#   'price': '429',
#   'rating': '3.1',
#   'oprice': '₹429'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Black Dial Colored Strap)  ",
#   'price': '319',
#   'rating': '4.2',
#   'oprice': '₹319'},
#  {'brand': 'Titan',
#   'title': "Octane Analog Silver Dial Men's Watch-NL1650BM03/NP1650BM03  ",
#   'price': '3,445',
#   'rating': '4.3',
#   'oprice': '₹3,445'},
#  {'brand': 'Acnos',
#   'title': "Analogue Men's Watch (Pack of 3) (Multicolored Dial Multicolored Colored Strap)  ",
#   'price': '355',
#   'rating': '3.5',
#   'oprice': '₹355'},
#  {'brand': 'Casio',
#   'title': 'Enticer Analog Dial Watch  ',
#   'price': '3,395',
#   'rating': '4.3',
#   'oprice': '₹3,395'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Titan',
#   'title': "Ladies Neo-Ii Analog Rose Gold Dial Women's Watch-NL2480KM01  ",
#   'price': '2,396',
#   'rating': '4.4',
#   'oprice': '₹2,396'},
#  {'brand': 'DANIEL KLEIN',
#   'title': "Analog Gold Dial Women's Watch-DK11430-4  ",
#   'price': '2,394',
#   'rating': '4.2',
#   'oprice': '₹2,394'},
#  {'brand': 'SF',
#   'title': "Venus Digital Grey Dial Men's Watch-NL7982PP03  ",
#   'price': '475',
#   'rating': '4.1',
#   'oprice': '₹475'},
#  {'brand': 'Titan',
#   'title': "Ladies Neo Economy Analog White Dial Women's Watch 2639SL04/NN2639SL04/NP2639SL04  ",
#   'price': '1,596',
#   'rating': '4.4',
#   'oprice': '₹1,596'},
#  {'brand': 'BY BENYAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '2,890',
#   'rating': '4.3',
#   'oprice': '₹2,890'},
#  {'brand': 'Diesel',
#   'title': "Axial Digital Black Dial Men's Watch-DZT2017  ",
#   'price': '10,398',
#   'rating': '3.8',
#   'oprice': '₹10,398'},
#  {'brand': 'TIMEX',
#   'title': "Analog Gold Dial Women's Watch-TW000Q810  ",
#   'price': '2,249',
#   'rating': '4.4',
#   'oprice': '₹2,249'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'FORSINING',
#   'title': "Automatic Mechanical Skeleton Transparent Analog Mesh Steel Band Men's Watch - FSG8181  ",
#   'price': '3,954',
#   'rating': '3.4',
#   'oprice': '₹3,954'},
#  {'brand': 'SF',
#   'title': "Digital Grey Round Dial Men's Sport Watch-NN77072PP04  ",
#   'price': '599',
#   'rating': '4.3',
#   'oprice': '₹599'},
#  {'brand': 'Joker & Witch',
#   'title': 'Phile Black Dial NATO Watch  ',
#   'price': '786',
#   'rating': '3.7',
#   'oprice': '₹786'},
#  {'brand': 'Mizi',
#   'title': 'Mizi Portable Samsung Galaxy Watch 5/4 / 3 Charger USB Travel Cordless Wireless Charger Keychain for Samsung Galaxy Watch 4 Classic Watch 3 Active Active 2 Gear S3 - Black  ',
#   'price': '599',
#   'rating': '4.2',
#   'oprice': '₹599'},
#  {'brand': 'NEO VICTORY',
#   'title': "Digital Baby Boy's Watch (Black Dial Black Colored Strap)  ",
#   'price': '185',
#   'rating': '2.9',
#   'oprice': '₹185'},
#  {'brand': 'Sonata',
#   'title': "Super Fibre Digital Grey Dial Men's Watch-NL87012PP03/NP87012PP03  ",
#   'price': '585',
#   'rating': '4.1',
#   'oprice': '₹585'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '249',
#   'rating': '4.1',
#   'oprice': '₹249'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Minute Track Dial Stainless Steel Chain Watch for Men  ',
#   'price': '279',
#   'rating': '3.9',
#   'oprice': '₹279'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.7',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'LOUIS DEVIN',
#   'title': 'Stainless Steel Chain Analog Wrist Watch for Men (Black/Silver/Blue) | LD-WT052  ',
#   'price': '299',
#   'rating': '3.4',
#   'oprice': '₹299'},
#  {'brand': 'AUREX',
#   'title': "Analogue Men's Watch (Silver Dial Silver Colored Strap)  ",
#   'price': '322',
#   'rating': '3.9',
#   'oprice': '₹322'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': 'HEMT',
#   'title': "Analog Men's Watch (Multi Color Dial Gold Colored Strap)  ",
#   'price': '449',
#   'rating': '3.6',
#   'oprice': '₹449'},
#  {'brand': 'PAPIO',
#   'title': "PU Belt Analogue Men's Watch and Boy's Watch  ",
#   'price': '199',
#   'rating': '4.7',
#   'oprice': '₹199'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Black Dial Colored Strap)  ",
#   'price': '319',
#   'rating': '4.2',
#   'oprice': '₹319'},
#  {'brand': 'Sylvi',
#   'title': "Multi-Functional Boys Casual Business Mens Luxury Stylish Watch Black Dial Leather Strap Wrist Watches for Men-Daily Use Analog Digital Sports Men's Watch  ",
#   'price': '986',
#   'rating': '3.9',
#   'oprice': '₹986'},
#  {'brand': 'PAPIO',
#   'title': "Digital Men's Watch (Black Dial Multi Colored Strap)  ",
#   'price': '449',
#   'rating': '3.7',
#   'oprice': '₹449'},
#  {'brand': 'A',
#   'title': 'Acnos Brand 3 Color Watch with Black PU Strap Watch M2 Digital for Mens and Watches for Boy Pack of-2  ',
#   'price': '284',
#   'rating': '3.5',
#   'oprice': '₹284'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '249',
#   'rating': '4.1',
#   'oprice': '₹249'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Minute Track Dial Stainless Steel Chain Watch for Men  ',
#   'price': '279',
#   'rating': '3.9',
#   'oprice': '₹279'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Minute Track Dial Stainless Steel Chain Watch for Men  ',
#   'price': '279',
#   'rating': '3.9',
#   'oprice': '₹279'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Black Dial Colored Strap)  ",
#   'price': '319',
#   'rating': '4.2',
#   'oprice': '₹319'},
#  {'brand': 'TIMEX',
#   'title': "Analog Black Dial Men's Watch-TW000R438  ",
#   'price': '1,769',
#   'rating': '4.1',
#   'oprice': '₹1,769'},
#  {'brand': 'TIMEX',
#   'title': 'TW000R434  ',
#   'price': '1,179',
#   'rating': '4.0',
#   'oprice': '₹1,179'},
#  {'brand': 'FASHOKART',
#   'title': "Men's Military Watches Outdoor Sports Digital Watch Waterproof LED Date Alarm Wrist Watches for Men 8007 Dark Green  ",
#   'price': '989',
#   'rating': 'M.R.P: ',
#   'oprice': '₹989'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'Matrix',
#   'title': 'Black, Blue, White Dial, Day & Date Functioning, Stainless Steel Strap Analog Watch for Men & Women  ',
#   'price': '329',
#   'rating': '3.0',
#   'oprice': '₹329'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': '1,999.',
#   'rating': None,
#   'oprice': '₹1,999.00'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'Carlson Raulen',
#   'title': 'Mens Chronograph Waterproof Luxury Fashion Military Quartz Sports Analog Wristwatches  ',
#   'price': '2,199',
#   'rating': '4.4',
#   'oprice': '₹2,199'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Day Date Functioning Stainless Steel Chain Watch for Men  ',
#   'price': '319',
#   'rating': '3.8',
#   'oprice': '₹319'},
#  {'brand': 'TrendyTap',
#   'title': 'TrendyTap Analog Unisex Child Watch (Red Dial Red Colored Strap)  ',
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'TIMEWEAR',
#   'title': 'Analog Minute Track Dial Stainless Steel Chain Watch for Men  ',
#   'price': '279',
#   'rating': '3.9',
#   'oprice': '₹279'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Black Dial Colored Strap)  ",
#   'price': '319',
#   'rating': '4.2',
#   'oprice': '₹319'},
#  {'brand': 'FASHOKART',
#   'title': "Men's Military Watches Outdoor Sports Digital Watch Waterproof LED Date Alarm Wrist Watches for Men 8007 Dark Green  ",
#   'price': '989',
#   'rating': 'New to Amazon',
#   'oprice': '₹989'},
#  {'brand': 'FASHOKART',
#   'title': "Men's Military Watches Outdoor Sports Digital Watch Waterproof LED Date Alarm Wrist Watches for Men 8007 Green  ",
#   'price': '989',
#   'rating': 'New to Amazon',
#   'oprice': '₹989'},
#  {'brand': 'TIMEX',
#   'title': 'TWHG03SMU04  ',
#   'price': '3,199',
#   'rating': '4.1',
#   'oprice': '₹3,199'},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None},
#  {'brand': 'TIMEWEAR',
#   'title': "Men's Analog Number Dial Brown Leather Strap Watch  ",
#   'price': '201',
#   'rating': '3.8',
#   'oprice': '₹201'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '399',
#   'rating': '3.8',
#   'oprice': '₹399'},
#  {'brand': 'Acnos',
#   'title': "Brand - A Digital Watch with Square LED Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Watch for Men's Kids Watch for Boys - Watch for Men  ",
#   'price': '325',
#   'rating': '3.6',
#   'oprice': '₹325'},
#  {'brand': 'TIMEWEAR',
#   'title': "Analog Men's Watch (Dial Colored Strap)  ",
#   'price': '249',
#   'rating': '4.1',
#   'oprice': '₹249'},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': '\n                                                    watch for boys\n                                                ',
#   'oprice': None},
#  {'brand': None,
#   'title': None,
#   'price': None,
#   'rating': ' or ',
#   'oprice': None},
#  {'brand': None, 'title': None, 'price': None, 'rating': None, 'oprice': None}]

# %%
import pandas as pd
pd.DataFrame(all_data).dropna(how='any').to_excel('amazon.xlsx', index=False)

# %% [markdown]
# install these packages using pip
#
# ```python
# pip install seaborn matplotlib plotly numpy streamlit flask sqlalchemy scikit-learn --upgrade
# ```
