# %% [markdown]
# run in terminal
# ```pip install dputils```

# %%
from dputils.scrape import Scraper, Tag

# %%
url = 'https://www.flipkart.com/search?q=bags&page=10'
sc = Scraper(url)

# %%
target = Tag('div', cls = '_1YokD2 _3Mn1Gg') # important
items = Tag('div', cls = '_1xHGtK _373qXS') # important repeating item
brand = Tag('div', cls = '_2WkVRV')
details = Tag('a', cls='IRpwTa')
price = Tag('div', cls='_30jeq3')
color = Tag('div', cls='_3eWWd-')
discount = Tag('div', cls='_3Ay6Sb')

# %%
data = sc.get_all(
        target, items, brand=brand,
        details=details, price=price,
        color=color, discount=discount
)
print(len(data))
# Out:
# 40

# %%
data
# Out:
# [{'brand': 'BTS',
#   'details': 'Small 12 L Backpack Denim Backpack',
#   'price': '₹499',
#   'color': 'Blue',
#   'discount': '54% off'},
#  {'brand': 'SKY RISE',
#   'details': 'Large 45 L Laptop Backpack medium backpack bags laptop ...',
#   'price': '₹431',
#   'color': 'Black',
#   'discount': '74% off'},
#  {'brand': 'Hilfiger',
#   'details': 'Small 19 L Backpack Waterproof Backpack,',
#   'price': '₹314',
#   'color': 'Blue, White',
#   'discount': '60% off'},
#  {'brand': 'ZCRAFT',
#   'details': 'Medium 25 L Backpack DAYPACK Bags Backpack for daily us...',
#   'price': '₹299',
#   'color': 'Black',
#   'discount': '70% off'},
#  {'brand': 'Lunar',
#   'details': 'Large 35 L Backpack Comet',
#   'price': '₹799',
#   'color': 'Black',
#   'discount': '52% off'},
#  {'brand': 'AMERICAN TOURISTER',
#   'details': 'Large 34 L Backpack HD Cuzy Polyester Sest+2 Blue unise...',
#   'price': '₹1,899',
#   'color': 'Blue',
#   'discount': '9% off'},
#  {'brand': 'QUEACHUA',
#   'details': 'Small 10 L Backpack Quechua Bags 10 L',
#   'price': '₹296',
#   'color': 'Blue',
#   'discount': '70% off'},
#  {'brand': 'PROVOGUE',
#   'details': '41.5 L Laptop Backpack Spacy Freeride Unisex Bag with r...',
#   'price': '₹726',
#   'color': 'Multicolor',
#   'discount': '83% off'},
#  {'brand': 'Lunar',
#   'details': 'Large 35 L Backpack V Line - 3 Compartment College | Sc...',
#   'price': '₹749',
#   'color': 'Black, White',
#   'discount': '58% off'},
#  {'brand': 'INSPIRE',
#   'details': 'Large 75 L Backpack 2 pcs Rucksack and Sling bag Combo',
#   'price': '₹1,521',
#   'color': 'Multicolor',
#   'discount': '67% off'},
#  {'brand': 'MAIZO',
#   'details': 'Small 12 L Backpack Small Backpack/School/Travel/Fancy ...',
#   'price': '₹279',
#   'color': 'Yellow',
#   'discount': '44% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack HARDROCK Unisex Backpack wit...',
#   'price': '₹838',
#   'color': 'Tan',
#   'discount': '76% off'},
#  {'brand': 'Roadster',
#   'details': 'Medium 22 L Backpack Slash Backpack',
#   'price': '₹627',
#   'color': 'Black',
#   'discount': '65% off'},
#  {'brand': 'PROVOGUE',
#   'details': '35.2 L Laptop Backpack Unisex Bag with rain cover Offic...',
#   'price': '₹730',
#   'color': 'Multicolor',
#   'discount': '85% off'},
#  {'brand': 'Lunar',
#   'details': 'Large 35 L Backpack Comet 4',
#   'price': '₹799',
#   'color': 'Blue, Black',
#   'discount': '52% off'},
#  {'brand': 'Wildcraft',
#   'details': 'Small 17 L Backpack Zeal',
#   'price': '₹779',
#   'color': 'Red',
#   'discount': '56% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 24 L Backpack NEW NEON 7 SCHOOL BAG (H) GREEN',
#   'price': '₹949',
#   'color': 'Green',
#   'discount': '56% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 25 L Laptop Backpack CHESTER PRO 02 LAPTOP BACKP...',
#   'price': '₹2,039',
#   'color': 'Blue',
#   'discount': '46% off'},
#  {'brand': 'CSZ',
#   'details': 'Small 18 L Backpack 18 L Printed Drawstring Polyester b...',
#   'price': '₹242',
#   'color': 'Black',
#   'discount': '51% off'},
#  {'brand': 'TRAVEL POINT',
#   'details': 'Medium 25 L Laptop Backpack for Office/College/School/T...',
#   'price': '₹437',
#   'color': 'Black, Yellow',
#   'discount': '85% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Small 17 L Backpack Lit17L Daypack Yellow',
#   'price': '₹679',
#   'color': 'Yellow',
#   'discount': '47% off'},
#  {'brand': 'REEBOK',
#   'details': 'Large 33 L Backpack Tech Style Bp M',
#   'price': '₹2,739',
#   'color': 'Grey',
#   'discount': '21% off'},
#  {'brand': 'SAFARI',
#   'details': 'Large 38 L Backpack Tint',
#   'price': '₹1,350',
#   'color': 'Grey',
#   'discount': '60% off'},
#  {'brand': 'SKY RISE',
#   'details': 'Large 45 L Laptop Backpack medium backpack bags laptop ...',
#   'price': '₹419',
#   'color': 'Blue',
#   'discount': '75% off'},
#  {'brand': 'TRAVEL POINT',
#   'details': 'Medium 25 L Laptop Backpack for Office/College/School/T...',
#   'price': '₹499',
#   'color': 'Black, White',
#   'discount': '83% off'},
#  {'brand': 'fellow',
#   'details': 'Large 60 L Backpack Large 60L School Bag Casual Bag Day...',
#   'price': '₹599',
#   'color': 'Grey',
#   'discount': '80% off'},
#  {'brand': 'REEBOK',
#   'details': 'Medium 22 L Laptop Backpack Bags',
#   'price': '₹586',
#   'color': 'Grey',
#   'discount': '54% off'},
#  {'brand': 'SKY RISE',
#   'details': 'Large 45 L Laptop Backpack medium backpack bags laptop ...',
#   'price': '₹419',
#   'color': 'Blue',
#   'discount': '75% off'},
#  {'brand': 'PUMA',
#   'details': 'Large 34 L Backpack One Spacious Unisex Multpurpose bag...',
#   'price': '₹1,339',
#   'color': 'Blue',
#   'discount': '50% off'},
#  {'brand': 'PROVOGUE',
#   'details': '41.5 L Laptop Backpack Spacy Freeride unisex bag with r...',
#   'price': '₹726',
#   'color': 'Black',
#   'discount': '75% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Large 32 L Backpack Chase 03',
#   'price': '₹1,499',
#   'color': 'Blue',
#   'discount': '58% off'},
#  {'brand': 'Vitaan',
#   'details': 'Large 35 L Backpack BlackGreen Backpack for Men and Wom...',
#   'price': '₹549',
#   'color': 'Black, Green',
#   'discount': '72% off'},
#  {'brand': 'ZIPLINE',
#   'details': 'Large 36 L Backpack Big Storage bags men :: Casual coll...',
#   'price': '₹889',
#   'color': 'Grey',
#   'discount': '53% off'},
#  {'brand': 'sky spirit',
#   'details': 'Large 50 L Backpack Backpack large 50L for Outdoor Spor...',
#   'price': '₹445',
#   'color': 'Grey',
#   'discount': '77% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 23 L Backpack Boho 01 With Raincover',
#   'price': '₹1,355',
#   'color': 'Black',
#   'discount': '45% off'},
#  {'brand': 'aob',
#   'details': 'Large 70 L Backpack UNISEX WaterProof Mountain Rucksack...',
#   'price': '₹599',
#   'color': 'Grey',
#   'discount': '80% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 30 L Backpack New Neon 11',
#   'price': '₹1,140',
#   'color': 'Blue',
#   'discount': '47% off'},
#  {'brand': 'ADIDAS',
#   'details': 'Medium 23 L Backpack LIN CLAS BP DAY',
#   'price': '₹949',
#   'color': 'Black',
#   'discount': '40% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 28 L Backpack Polyester 28L Drip Plus 04 Backpac...',
#   'price': '₹1,895',
#   'color': 'Blue',
#   'discount': '24% off'},
#  {'brand': 'WROGN',
#   'details': 'Medium 30 L Laptop Backpack Backpack For College School...',
#   'price': '₹323',
#   'color': 'Blue, Black',
#   'discount': '89% off'}]
