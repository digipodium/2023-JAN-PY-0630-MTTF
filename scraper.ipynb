# %% [markdown]
# run in terminal
# ```pip install dputils```

# %%
from dputils.scrape import Scraper, Tag

# %%
url = 'https://www.flipkart.com/search?q=bags&page=10'
sc = Scraper(url)

# %%
target = Tag('div', cls = '_1YokD2 _3Mn1Gg') # important
items = Tag('div', cls = '_1xHGtK _373qXS') # important repeating item
brand = Tag('div', cls = '_2WkVRV')
details = Tag('a', cls='IRpwTa')
price = Tag('div', cls='_30jeq3')
color = Tag('div', cls='_3eWWd-')
discount = Tag('div', cls='_3Ay6Sb')

# %%
data = sc.get_all(
        target, items, brand=brand,
        details=details, price=price,
        color=color, discount=discount
)
print(len(data))
# Out:
# 40

# %%
data
# Out:
# [{'brand': 'PROVOGUE',
#   'details': '35.5 L Laptop Backpack Unisex bag with rain cover Lapto...',
#   'price': '₹775',
#   'color': 'Multicolor',
#   'discount': '77% off'},
#  {'brand': 'PROVOGUE',
#   'details': '35.2 L Laptop Backpack Unisex Bag with rain cover Offic...',
#   'price': '₹780',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'sky spirit',
#   'details': 'Large 40 L Laptop Backpack Waterproof Large 40L Laptop ...',
#   'price': '₹374',
#   'color': 'Green',
#   'discount': '81% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Large 45 L Laptop Backpack Unisex Bag with rain cover O...',
#   'price': '₹780',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 30 L Backpack New Neon 11',
#   'price': '₹1,190',
#   'color': 'Blue',
#   'discount': '45% off'},
#  {'brand': 'MAIZO',
#   'details': 'Small 10 L Backpack Small Backpack with 3-Zip Waist Bag...',
#   'price': '₹499',
#   'color': 'Black',
#   'discount': '16% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 40 L Laptop Backpack Spacy Freeride Unisex Bag wi...',
#   'price': '₹780',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'ZCRAFT',
#   'details': 'Medium 25 L Backpack DAYPACK Bags Backpack for daily us...',
#   'price': '₹299',
#   'color': 'Black',
#   'discount': '70% off'},
#  {'brand': 'PROVOGUE',
#   'details': '39.5 L Laptop Backpack Large Laptop Backpack Spacy unis...',
#   'price': '₹739',
#   'color': 'Multicolor',
#   'discount': '81% off'},
#  {'brand': 'HP',
#   'details': 'Medium 22 L Backpack 15.6 inch Laptop Backpack with 2 C...',
#   'price': '₹955',
#   'color': 'Blue',
#   'discount': '46% off'},
#  {'brand': 'HP',
#   'details': 'Small 20 L Backpack Evon Essential Laptop Black Backpac...',
#   'price': '₹606',
#   'color': 'Grey',
#   'discount': '49% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Large 40 L Laptop Backpack Unisex Bag with rain cover O...',
#   'price': '₹780',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'KILLER',
#   'details': 'Large 33 L Backpack Casual Backpack - Access 33 Ltr Gre...',
#   'price': '₹777',
#   'color': 'Grey, Orange',
#   'discount': '48% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Large 32 L Backpack Chase 03',
#   'price': '₹1,549',
#   'color': 'Blue',
#   'discount': '56% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 25 L Laptop Backpack CHESTER PRO 02 LAPTOP BACKP...',
#   'price': '₹2,089',
#   'color': 'Grey',
#   'discount': '45% off'},
#  {'brand': 'PROVOGUE',
#   'details': '41.5 L Laptop Backpack Spacy Freeride Unisex Bag with r...',
#   'price': '₹776',
#   'color': 'Multicolor',
#   'discount': '82% off'},
#  {'brand': 'AMERICAN TOURISTER',
#   'details': 'Medium 22 L Backpack ACE DAYPACK - MAGENTA',
#   'price': '₹929',
#   'color': 'Purple',
#   'discount': '35% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 25 L Laptop Backpack CHESTER PRO 02 LAPTOP BACKP...',
#   'price': '₹2,090',
#   'color': 'Blue',
#   'discount': '45% off'},
#  {'brand': 'Skybags',
#   'details': 'Medium 23 L Backpack Boho 01 With Raincover',
#   'price': '₹1,690',
#   'color': 'Blue',
#   'discount': '39% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack HARDROCK Unisex Backpack wit...',
#   'price': '₹888',
#   'color': 'Tan',
#   'discount': '74% off'},
#  {'brand': 'Gear',
#   'details': 'Medium 25 L Backpack Campus 8 Backpack',
#   'price': '₹629',
#   'color': 'Blue, Brown',
#   'discount': '51% off'},
#  {'brand': 'RB Suffer',
#   'details': 'Small 18 L Backpack Small Backpack Small Size Bag for D...',
#   'price': '₹269',
#   'color': 'Multicolor',
#   'discount': '70% off'},
#  {'brand': 'LO4VO',
#   'details': 'Small 10 L Backpack SCHOOL/COLLEGE BAGS FOR GIRLS/WOMEN',
#   'price': '₹369',
#   'color': 'Grey',
#   'discount': '63% off'},
#  {'brand': 'aob',
#   'details': 'Large 70 L Backpack UNISEX WaterProof Mountain Rucksack...',
#   'price': '₹649',
#   'color': 'Grey',
#   'discount': '78% off'},
#  {'brand': 'Gear',
#   'details': 'Medium 29 L Backpack GRAFFITTI WITH RAINCOVER BACKPACK',
#   'price': '₹809',
#   'color': 'Black, Blue',
#   'discount': '59% off'},
#  {'brand': 'F GEAR',
#   'details': 'Medium 27 L Backpack Axe',
#   'price': '₹1,199',
#   'color': 'Blue, Black',
#   'discount': '35% off'},
#  {'brand': 'Luzian',
#   'details': 'Medium 30 L Backpack BACKPACK',
#   'price': '₹449',
#   'color': 'Black',
#   'discount': '77% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Large 45 L Laptop Backpack Unisex Bag with rain cover O...',
#   'price': '₹780',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'AMERICAN TOURISTER',
#   'details': 'Large 34 L Backpack HD Cuzy Polyester Sest+2 Blue unise...',
#   'price': '₹1,890',
#   'color': 'Blue',
#   'discount': '10% off'},
#  {'brand': 'QUEACHUA',
#   'details': 'Small 10 L Backpack Quechua Bags 10 L',
#   'price': '₹329',
#   'color': 'Blue',
#   'discount': '67% off'},
#  {'brand': 'PUMA',
#   'details': 'Large 34 L Backpack One Spacious Unisex Multpurpose bag...',
#   'price': '₹1,419',
#   'color': 'Yellow',
#   'discount': '47% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Large 40 L Laptop Backpack Unisex Bag with rain cover O...',
#   'price': '₹780',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'Roadster',
#   'details': 'Medium 21 L Backpack Sprint Backpack',
#   'price': '₹496',
#   'color': 'Black',
#   'discount': '75% off'},
#  {'brand': 'F GEAR',
#   'details': 'Small 7 L Backpack Ferris P2 Green',
#   'price': '₹499',
#   'color': 'Green',
#   'discount': '49% off'},
#  {'brand': 'SAFARI',
#   'details': 'Medium 26 L Backpack JERSEY 26L NAVY BLUE BACKPACK',
#   'price': '₹746',
#   'color': 'Red, Blue',
#   'discount': '56% off'},
#  {'brand': 'zikrefast',
#   'details': 'Large 35 L Laptop Backpack Medium 35 L Backpack Premium...',
#   'price': '₹394',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'Gear',
#   'details': 'Small 19 L Backpack ECO 4 BACKPACK',
#   'price': '₹539',
#   'color': 'Black',
#   'discount': '50% off'},
#  {'brand': 'Roadster',
#   'details': 'Medium 30 L Laptop Backpack for College/ School/ Travel...',
#   'price': '₹599',
#   'color': 'Black, Yellow',
#   'discount': '80% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Small 15 L Backpack Unisex Backpack For School/Office/T...',
#   'price': '₹349',
#   'color': 'Black',
#   'discount': '76% off'},
#  {'brand': 'TRAVEL POINT',
#   'details': 'Medium 25 L Laptop Backpack for Office/College/School/T...',
#   'price': '₹486',
#   'color': 'Black, Yellow',
#   'discount': '83% off'}]
